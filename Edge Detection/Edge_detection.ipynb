# %%
import cv2
import os
from matplotlib import pyplot as plt

# %%
img_path = "i.jpeg"

# %%
img = cv2.imread(img_path)

# %%
img
# Out:
# array([[[ 89,  70,   2],
#         [ 90,  71,   3],
#         [ 90,  71,   3],
#         ...,
#         [125, 107,   6],
#         [125, 107,   6],
#         [125, 107,   6]],
#
#        [[ 90,  71,   3],
#         [ 90,  71,   3],
#         [ 91,  72,   4],
#         ...,
#         [125, 107,   6],
#         [125, 107,   6],
#         [125, 107,   6]],
#
#        [[ 90,  71,   3],
#         [ 91,  72,   4],
#         [ 91,  72,   4],
#         ...,
#         [125, 107,   6],
#         [125, 107,   6],
#         [125, 107,   6]],
#
#        ...,
#
#        [[  9,   0,   3],
#         [  9,   0,   3],
#         [  9,   0,   3],
#         ...,
#         [  3,   0,   2],
#         [  3,   0,   2],
#         [  3,   0,   2]],
#
#        [[  9,   0,   3],
#         [  9,   0,   3],
#         [  9,   0,   3],
#         ...,
#         [  3,   0,   2],
#         [  3,   0,   2],
#         [  3,   0,   2]],
#
#        [[  9,   0,   3],
#         [  9,   0,   3],
#         [  9,   0,   3],
#         ...,
#         [  3,   0,   2],
#         [  3,   0,   2],
#         [  3,   0,   2]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
resized_img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
cv2.imshow('cmera image',resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
(int(img.shape[1]/2), int(img.shape[0]/2))
# Out:
# (1000, 571)

# %% [markdown]
# Apply Canny Edge Detection Algorithm

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5,5), 0)
canny = cv2.Canny(blur, threshold1 = 180, threshold2= 200)

# %%
resized_img = cv2.resize(canny, (int(img.shape[1]/2), int(img.shape[0]/2)))
cv2.imshow('cmera image',resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('camrea_Edges.jpeg',canny)
# Out:
# True
